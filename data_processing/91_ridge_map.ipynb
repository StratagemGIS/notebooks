# %% [markdown]
# <a href="https://colab.research.google.com/github/StratagemGIS/notebooks/blob/main/data_processing/91_ridge_map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Vaasudevan Srinivasan 🧑🏻‍💻
# StratagemGIS Solutions

# %%
# %%capture
# !pip install ridge_map

# %%
import matplotlib.pyplot as plt
from ridge_map import RidgeMap

# %%
rm = RidgeMap((-66.986, 47.286, -66.667, 47.527))

values = rm.get_elevation_data(num_lines=300)

values=rm.preprocess(
    values=values,
    lake_flatness=2,
    water_ntile=10,
    vertical_ratio=240
)

rm.plot_map(
    values=values,
    label='Mount Carleton \nProvincial Park',
    label_y=0.1,
    label_x=0.55,
    label_size=40,
    linewidth=2
)

plt.savefig('ridge_map.png', bbox_inches='tight', dpi=600);
