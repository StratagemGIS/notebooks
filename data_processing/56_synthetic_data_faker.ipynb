# %% [markdown]
# <a href="https://colab.research.google.com/github/StratagemGIS/notebooks/blob/main/data_processing/56_synthetic_data_faker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Vaasudevan Srinivasan 🧑🏻‍💻
# StratagemGIS Solutions

# %%
# !pip install faker

# %%
import pandas as pd
from faker import Faker

# %%
Faker.seed(2)
fake = Faker()

df = pd.DataFrame({
    'name': [fake.name() for i in range(5)],
    'email': [fake.email() for i in range(5)],
    'country': [fake.country() for i in range(5)],
    'username': [fake.user_name() for i in range(5)],
    'dob': [fake.date_of_birth() for i in range(5)]
})

df
# Out:
#                  name                     email                  country  \
# 0       Theresa Brown         amy78@example.com                     Peru
# 1  Russell Fitzgerald  pittsmichael@example.com                   Monaco
# 2    Elizabeth Obrien    hhenderson@example.org  Cocos (Keeling) Islands
# 3        Lauren Moore   joeljohnson@example.com                   Uganda
# 4         James Sharp  derrickdixon@example.net                 Kiribati
#
#        username         dob
# 0      wnavarro  1966-08-16
# 1    kristine55  2004-12-24
# 2       wmartin  1949-07-31
# 3     despinoza  2010-12-08
# 4  tracybuckley  2012-11-21

# %%
fake.profile()
# Out:
# {'job': 'Psychologist, clinical',
#  'company': 'Bradley-Knapp',
#  'ssn': '742-59-7973',
#  'residence': '294 Collins Union Suite 437\nSarahland, WY 45256',
#  'current_location': (Decimal('-87.739285'), Decimal('-77.241443')),
#  'blood_group': 'A-',
#  'website': ['http://perez.net/'],
#  'username': 'hendersonjennifer',
#  'name': 'Danielle Clark',
#  'sex': 'F',
#  'address': '2301 Stephanie Burg Apt. 054\nPort Sharon, WA 24584',
#  'mail': 'cruzbradley@gmail.com',
#  'birthdate': datetime.date(1926, 2, 2)}
