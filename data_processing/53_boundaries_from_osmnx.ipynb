# %% [markdown]
# <a href="https://colab.research.google.com/github/StratagemGIS/notebooks/blob/main/data_processing/53_boundaries_from_osmnx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Vaasudevan Srinivasan 🧑🏻‍💻
# StratagemGIS Solutions

# %%
# !pip install osmnx

# %%
import osmnx as ox

# %%
ox.geocode_to_gdf('Fredericton').plot();

# %%
ox.geocode_to_gdf('India').plot();
