# %% [markdown]
# <a href="https://colab.research.google.com/github/StratagemGIS/notebooks/blob/main/data_processing/79_movingbubbles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Vaasudevan Srinivasan 🧑🏻‍💻
# StratagemGIS Solutions

# %%
# %%capture
# !pip install d3blocks

# %%
import numpy as np
import pandas as pd
from d3blocks import D3Blocks

# %%
# @title Dataset Preparation

np.random.seed(2024)

n = 250  # Number of Students

activities = [
    'Attending Classes',
    'Studying',
    'Socializing',
    'Dining',
    'Exercising',
    'Volunteering',
    'Relaxing',
    'Group Projects',
    'Attending Events'
]

datetime = (
    pd.to_datetime('2025-01-01') +
    pd.to_timedelta(np.random.rand(n * len(activities)) * 86400, unit='s')
)

students_df = pd.DataFrame(
    {
        'datetime': datetime,
        'sample_id': np.random.choice(range(0, n), size=n * len(activities)),
        'state': np.random.choice(activities, size=n * len(activities))
     }
)

# %%
students_df.sample(5, random_state=2024)
# Out:
#                           datetime  sample_id             state
# 1789 2025-01-01 09:12:48.544657294        144  Attending Events
# 1212 2025-01-01 02:59:46.528699245        198          Relaxing
# 2134 2025-01-01 20:59:53.093993610        195    Group Projects
# 1052 2025-01-01 10:51:26.700807035         30          Relaxing
# 6    2025-01-01 17:27:13.548414337          4          Relaxing

# %%
d3 = D3Blocks(chart='movingbubbles')
d3.movingbubbles(students_df, figsize=(775, 800))
# Out:
# [d3blocks] >INFO> Cleaning edge_properties and config parameters..
# [d3blocks] >INFO> Initializing [Movingbubbles]
# [d3blocks] >INFO> Create directory: [/tmp/d3blocks]
# [d3blocks] >INFO> filepath is set to [/tmp/d3blocks/movingbubbles.html]
# [d3blocks] >INFO> Cleaning edge_properties and config parameters..
# [d3blocks] >INFO> Initializing [Movingbubbles]
# [d3blocks] >INFO> filepath is set to [/tmp/d3blocks/movingbubbles.html]
# [d3blocks] >INFO> Convert to DataFrame.
# [d3blocks] >INFO> Node properties are set.
# [d3blocks] >INFO> Standardizing input dataframe using method: [samplewise].
# [d3blocks] >INFO> Standardize method: [samplewise]
# 100%|██████████| 250/250 [00:00<00:00, 289.70it/s]
# [d3blocks] >INFO> Set all nodes to size: 5
# [clustimage] >WARNING> Colormap [Set1] can not create [250] unique colors! Available unique colors: [9].
# [d3blocks] >WARNING> Colormap [Set1] can not create [250] unique colors! Available unique colors: [9].
# ...
