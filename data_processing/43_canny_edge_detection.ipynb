# %% [markdown]
# <a href="https://colab.research.google.com/github/StratagemGIS/notebooks/blob/main/data_processing/43_canny_edge_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Vaasudevan Srinivasan 🧑🏻‍💻
# StratagemGIS Solutions

# %%
# !pip install rasterio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 23.0 MB/s eta 0:00:00
# ...

# %%
import cv2
import matplotlib.pyplot as plt
import pooch
import rasterio as rio
import rasterio.plot as ras_plot

# %%
u22_file = pooch.retrieve(
    'https://github.com/StratagemGIS/datasets/raw/main/raster/U22.tif',
    known_hash='e31ab10ca0a6f917c3bba2eea5d0e1a8c3ed0fde4e8b9174183019bb9f830c74'
)

# %%
with rio.open(u22_file) as src:
    img = ras_plot.reshape_as_image(src.read())[3500:4500, 3000:4000, :]

blurred_image = cv2.GaussianBlur(img, (7, 7), 0)
edges = cv2.Canny(blurred_image, threshold1=100, threshold2=125)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 10), constrained_layout=True)
ax[0].imshow(img)
ax[1].imshow(edges, cmap='gray')
ax[0].axis('off')
ax[1].axis('off')
plt.gcf().set_dpi(85);
