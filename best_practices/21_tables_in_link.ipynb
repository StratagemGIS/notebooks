# %% [markdown]
# <a href="https://colab.research.google.com/github/StratagemGIS/notebooks/blob/main/best_practices/21_tables_in_link.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_Earth_observation_satellites')

# %%
len(tables)
# Out:
# 8

# %%
tables[0].head()
# Out:
#               Name  Status                                             Agency  \
# 0           ALOS-2  Active                                               JAXA
# 1  Alsat-2A and 2B  Active                       Algerian Space Agency (ASAL)
# 2       Amazônia-1  Active  Brazil’s National Institute for Space Research...
# 3             Aqua  Active                                               NASA
# 4         ASNARO-2  Active                                               JAXA
#
#   Launch [note 1]                                        Description
# 0            2014                                                NaN
# 1            2016                                                NaN
# 2            2021                                                NaN
# 3            2002  Carries six instruments to observe interaction...
# 4            2018                                                NaN
