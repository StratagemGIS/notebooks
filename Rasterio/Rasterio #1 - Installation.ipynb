# %%
# !pip install rasterio
# Out:
# ...
#      |████████████████████████████████| 19.3 MB 5.3 MB/s
# ...

# %%
import rasterio

# %%
rasterio
# Out:
# <module 'rasterio' from '/usr/local/lib/python3.7/dist-packages/rasterio/__init__.py'>
